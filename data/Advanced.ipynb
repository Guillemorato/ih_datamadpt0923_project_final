# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
stats = pd.read_csv('./data/padel_player_dataset.csv')

# %%
Advanced_level = stats[stats['Skill Level'] == 'Advanced']
Advanced_level
# Out:
#        Player ID Age Group  Gender Skill Level  Errores No Forzados  Winners  \
# 1              2       >60  Female    Advanced                   26       23
# 2              3     31-45  Female    Advanced                   25       12
# 6              7     31-45  Female    Advanced                   34       18
# 10            11     46-60  Female    Advanced                    3       22
# 16            17     46-60    Male    Advanced                   30        3
# ...          ...       ...     ...         ...                  ...      ...
# 99989      99990       >60  Female    Advanced                   21        2
# 99994      99995     46-60    Male    Advanced                   45        1
# 99996      99997       <18    Male    Advanced                   43       24
# 99997      99998       >60  Female    Advanced                   46       19
# 99999     100000       <18    Male    Advanced                   17       13
#
# ...

# %%
Advanced_level_male = Advanced_level[Advanced_level['Gender'] == 'Male']
Advanced_level_male
# Out:
#        Player ID Age Group Gender Skill Level  Errores No Forzados  Winners  \
# 16            17     46-60   Male    Advanced                   30        3
# 34            35     31-45   Male    Advanced                   19       22
# 37            38       >60   Male    Advanced                   30        2
# 42            43     46-60   Male    Advanced                   25       21
# 46            47     18-30   Male    Advanced                   38       17
# ...          ...       ...    ...         ...                  ...      ...
# 99962      99963     18-30   Male    Advanced                    6        8
# 99975      99976       <18   Male    Advanced                   38        3
# 99994      99995     46-60   Male    Advanced                   45        1
# 99996      99997       <18   Male    Advanced                   43       24
# 99999     100000       <18   Male    Advanced                   17       13
#
# ...

# %%
Advanced_level_male = Advanced_level_male.sort_values(by= 'Age Group', ascending = True)
Advanced_level_male
# Out:
#        Player ID Age Group Gender Skill Level  Errores No Forzados  Winners  \
# 75629      75630     18-30   Male    Advanced                   20        4
# 74141      74142     18-30   Male    Advanced                   12        7
# 26227      26228     18-30   Male    Advanced                   18       22
# 26210      26211     18-30   Male    Advanced                   21        3
# 74148      74149     18-30   Male    Advanced                   11        2
# ...          ...       ...    ...         ...                  ...      ...
# 18274      18275       >60   Male    Advanced                   27        0
# 82344      82345       >60   Male    Advanced                   44       27
# 18268      18269       >60   Male    Advanced                   45       13
# 18413      18414       >60   Male    Advanced                   14        1
# 49587      49588       >60   Male    Advanced                    8       21
#
# ...

# %%
Advanced_level_male.to_csv('advanced_male.csv')

# %%
Advanced_level = stats[stats['Skill Level'] == 'Advanced']
Advanced_level
# Out:
#        Player ID Age Group  Gender Skill Level  Errores No Forzados  Winners  \
# 1              2       >60  Female    Advanced                   26       23
# 2              3     31-45  Female    Advanced                   25       12
# 6              7     31-45  Female    Advanced                   34       18
# 10            11     46-60  Female    Advanced                    3       22
# 16            17     46-60    Male    Advanced                   30        3
# ...          ...       ...     ...         ...                  ...      ...
# 99989      99990       >60  Female    Advanced                   21        2
# 99994      99995     46-60    Male    Advanced                   45        1
# 99996      99997       <18    Male    Advanced                   43       24
# 99997      99998       >60  Female    Advanced                   46       19
# 99999     100000       <18    Male    Advanced                   17       13
#
# ...

# %%
Advanced_level_female = Advanced_level[Advanced_level['Gender'] == 'Female']
Advanced_level_female
# Out:
#        Player ID Age Group  Gender Skill Level  Errores No Forzados  Winners  \
# 1              2       >60  Female    Advanced                   26       23
# 2              3     31-45  Female    Advanced                   25       12
# 6              7     31-45  Female    Advanced                   34       18
# 10            11     46-60  Female    Advanced                    3       22
# 31            32     46-60  Female    Advanced                   17        4
# ...          ...       ...     ...         ...                  ...      ...
# 99960      99961       <18  Female    Advanced                   42        7
# 99980      99981       <18  Female    Advanced                   40        9
# 99988      99989     46-60  Female    Advanced                    1        4
# 99989      99990       >60  Female    Advanced                   21        2
# 99997      99998       >60  Female    Advanced                   46       19
#
# ...

# %%
Advanced_level_female = Advanced_level_female.sort_values(by= 'Age Group', ascending = True)
Advanced_level_female
# Out:
#        Player ID Age Group  Gender Skill Level  Errores No Forzados  Winners  \
# 24250      24251     18-30  Female    Advanced                   39       13
# 71282      71283     18-30  Female    Advanced                   11        5
# 17568      17569     18-30  Female    Advanced                    8       23
# 17575      17576     18-30  Female    Advanced                   17       20
# 71263      71264     18-30  Female    Advanced                    5       28
# ...          ...       ...     ...         ...                  ...      ...
# 56169      56170       >60  Female    Advanced                   50        7
# 56147      56148       >60  Female    Advanced                   25       10
# 56133      56134       >60  Female    Advanced                   30       22
# 56318      56319       >60  Female    Advanced                   35       14
# 99997      99998       >60  Female    Advanced                   46       19
#
# ...

# %%
Advanced_level_female.to_csv('advanced_female.csv')
