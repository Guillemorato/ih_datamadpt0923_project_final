# %%
import numpy as np
import pandas as pd

# matplotlib
import matplotlib.pyplot as plt   

# seaborn
import seaborn as sns

# %%
advanced_male = pd.read_csv('./advanced_male.csv')

# %%
advanced_male.head()
# Out:
#    Unnamed: 0  Player ID Age Group Gender Skill Level  Errores No Forzados  \
# 0       75629      75630     18-30   Male    Advanced                   20
# 1       74141      74142     18-30   Male    Advanced                   12
# 2       26227      26228     18-30   Male    Advanced                   18
# 3       26210      26211     18-30   Male    Advanced                   21
# 4       74148      74149     18-30   Male    Advanced                   11
#
#    Winners  Puntos Ganados de Remate  % Primeros Saques  % Segundos Saques  \
# 0        4                         2                 99                 20
# 1        7                         0                 28                 11
# 2       22                        16                 90                  7
# 3        3                        21                  0                 39
# 4        2                         6                 65                  3
#
# ...

# %%
advanced_male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16561 entries, 0 to 16560
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             16561 non-null  int64
#  1   Player ID                              16561 non-null  int64
#  2   Age Group                              16561 non-null  object
#  3   Gender                                 16561 non-null  object
#  4   Skill Level                            16561 non-null  object
#  5   Errores No Forzados                    16561 non-null  int64
#  6   Winners                                16561 non-null  int64
#  7   Puntos Ganados de Remate               16561 non-null  int64
#  8   % Primeros Saques                      16561 non-null  int64
#  9   % Segundos Saques                      16561 non-null  int64
# ...

# %%
advanced_male_enf = ['Age Group','Errores No Forzados', 'Errores No Forzados de Fondo de Pista', 'Errores No Forzados en Red']
advanced_male_enf = advanced_male[advanced_male_enf]

# %%
advanced_male_enf
# Out:
#       Age Group  Errores No Forzados  Errores No Forzados de Fondo de Pista  \
# 0         18-30                   20                                     41
# 1         18-30                   12                                     43
# 2         18-30                   18                                      1
# 3         18-30                   21                                     24
# 4         18-30                   11                                     19
# ...         ...                  ...                                    ...
# 16556       >60                   27                                     48
# 16557       >60                   44                                     13
# 16558       >60                   45                                     23
# 16559       >60                   14                                      8
# 16560       >60                    8                                     47
#
#        Errores No Forzados en Red
# ...

# %%
fig, [ax1, ax2] = plt.subplots(1,2, figsize = [9,5])
mean_enf = advanced_male_enf[['Errores No Forzados', 'Errores No Forzados de Fondo de Pista', 'Errores No Forzados en Red']].groupby('Age Group').mean().reset_index()
ax1.set_xticks([])

ax1.plot(mean_enf['Months_encoded'], mean_month['Steps'])


mean_work = fitbit[['Steps', 'Work_or_Weekend']].groupby('Work_or_Weekend').mean().reset_index()
ax2.set_yticks([])
ax2.plot(mean_work['Work_or_Weekend'], mean_work['Steps'])


plt.show()

# %%
age_group = advanced_male_enf.groupby('Age Group')[['Errores No Forzados', 'Errores No Forzados de Fondo de Pista', 'Errores No Forzados en Red']].mean()

# Crear la figura
plt.figure(figsize=(10, 6))

# Crear el gráfico de barras
age_group.plot(kind='bar')

# Añadir título y etiquetas a los ejes
plt.title('Media de Errores No Forzados por Grupo de Edad')
plt.xlabel('Grupo de Edad')
plt.ylabel('Media de Errores No Forzados')

# Mostrar el gráfico
plt.show()
